# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-aept1j6i because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
# Example Venn
venn2(subsets = (10, 5, 2), set_labels = ('Group A', 'Group B'))
plt.show()

# %%
fig_dir = "/directflow/SCCGGroupShare/projects/anncuo/OneK1K/saige_eqtl/ms_figures/smr_venn/"

# %%
######################
######### CD #########
######################

# %%
# FDR < 5%
venn2(subsets = (150-116, 131-116, 116), set_labels = ('SAIGE-QTL', 'Matrix eQTL'), set_colors=('coral','red'))
plt.title("Significant SMR CD-eQTLs \nall 14 cell types")
plt.savefig(f"{fig_dir}SMR_CD_fdr.pdf")
plt.show()

# %%
######################
######## IBD #########
######################

# %%
# FDR < 5%
venn2(subsets = (304-214, 228-214, 214), set_labels = ('SAIGE-QTL', 'Matrix eQTL'), set_colors=('forestgreen','darkblue'))
plt.title("Significant SMR IBD-eQTLs \nall 14 cell types")
plt.savefig(f"{fig_dir}SMR_IBD_fdr.pdf")
plt.show()

# %%
######################
######### RA #########
######################

# %%
# FDR < 5%
venn2(subsets = (601-483, 449-483, 483), set_labels = ('SAIGE-QTL', 'Matrix eQTL'), set_colors=('gold','firebrick'))
plt.title("Significant SMR RA-eQTLs \nall 14 cell types")
plt.savefig(f"{fig_dir}SMR_RA_fdr.pdf")
plt.show()

# %%
######################
######### SLE ########
######################

# %%
# FDR < 5%
venn2(subsets = (21-0, 0-0, 0), set_labels = ('SAIGE-QTL', 'Matrix eQTL'), set_colors=('purple','firebrick'))
plt.title("Significant SMR SLE-eQTLs \nall 14 cell types")
plt.savefig(f"{fig_dir}SMR_SLE_fdr.pdf")
plt.show()
